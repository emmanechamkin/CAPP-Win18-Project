# %%
import pandas as pd
import numpy as np
import csv 
import os 
import re

# %%
CODEFILE = './nhgis0015_ds92_1960_tract_codebook.txt'
DATAFILE = './nhgis0015_ds92_1960_tract.csv'
OUTPUTFILE = './1960s_fordb.csv'

pd.set_option("display.max_rows",101)
pd.set_option("display.max_columns",101)
pd.set_option("display.max_seq_items",500)

# %%
f = open(CODEFILE, 'r')

# keep all lines that are not whitespace
lines = [line for line in f.readlines() if not line is ""]

lines
# Out:
# ['--------------------------------------------------------------------------------\n',
#  "Codebook for NHGIS data file 'nhgis0015_ds92_1960_tract'\n",
#  '--------------------------------------------------------------------------------\n',
#  ' \n',
#  'Contents\n',
#  '    - Data Summary\n',
#  '    - Data Dictionary\n',
#  '    - Citation and Use\n',
#  ' \n',
#  'Additional documentation on NHGIS data sources is available at: \n',
#  '    https://www.nhgis.org/documentation/tabular-data \n',
#  ' \n',
#  '--------------------------------------------------------------------------------\n',
#  'Data Summary\n',
#  '--------------------------------------------------------------------------------\n',
#  ' \n',
#  'Year:             1960\n',
#  'Geographic level: Census Tract (by State--County)\n',
#  'Dataset:          1960 Census: Population & Housing Data [Tracts: Major Cities & Surrounds]\n',
#  '   NHGIS code:    1960_tPH\n',
#  '   NHGIS ID:      ds92\n',
#  ' \n',
#  'Tables:\n',
#  ' \n',
#  '1. Total Persons\n',
#  '   Universe:    Persons\n',
#  '   Source code: NTSUP2\n',
#  '   NHGIS code:  CA4\n',
#  ' \n',
#  '2. Total Housing Units\n',
#  '   Universe:    Housing Units\n',
#  '   Source code: NTSUP3\n',
#  '   NHGIS code:  CA5\n',
#  ' \n',
#  '3. Owner-Occupied Housing Units Reporting Value\n',
#  '   Universe:    Owner-Occupied Housing Units Reporting Value\n',
#  '   Source code: NTSUP4\n',
#  '   NHGIS code:  CA6\n',
#  ' \n',
#  '4. White Persons by Household Relationship\n',
#  '   Universe:    White Persons\n',
#  '   Source code: NT1\n',
#  '   NHGIS code:  B7Z\n',
#  ' \n',
#  '5. Occupied Year-Round Housing Units by Tenure\n',
#  '   Universe:    Occupied Year-Round Housing Units\n',
#  '   Source code: NT2\n',
#  '   NHGIS code:  B8F\n',
#  ' \n',
#  '6. Vacant Year-Round Housing Units by Occupancy/Vacancy Status\n',
#  '   Universe:    Vacant Year-Round Housing Units\n',
#  '   Source code: NT3\n',
#  '   NHGIS code:  B8Q\n',
#  ' \n',
#  '7. Nonwhite Persons by Race by Sex\n',
#  '   Universe:    Nonwhite Persons\n',
#  '   Source code: NT17\n',
#  '   NHGIS code:  B8C\n',
#  ' \n',
#  '8. Persons by Race by Age by Sex\n',
#  '   Universe:    Persons\n',
#  '   Source code: NT20\n',
#  '   NHGIS code:  B8G\n',
#  ' \n',
#  '9. Persons 25 Years and Over by Years of School Completed\n',
#  '   Universe:    Persons 25 Years and Over\n',
#  '   Source code: NT30\n',
#  '   NHGIS code:  B8R\n',
#  ' \n',
#  '10. Persons 25 Years and Over by Years of School Completed\n',
#  '    Universe:    Nonwhite Persons 25 Years and Over\n',
#  '    Source code: NT31\n',
#  '    NHGIS code:  B8S\n',
#  ' \n',
#  '11. Persons 25 Years and Over by Years of School Completed\n',
#  '    Universe:    Puerto Rican or Spanish Surname Persons 25 Years and Over\n',
#  '    Source code: NT32\n',
#  '    NHGIS code:  B8T\n',
#  ' \n',
#  '12. Families by Income in 1959\n',
#  '    Universe:    Families\n',
#  '    Source code: NT35\n',
#  '    NHGIS code:  B8W\n',
#  ' \n',
#  '13. Nonwhite Families by Income in 1959\n',
#  '    Universe:    Nonwhite Families\n',
#  '    Source code: NT36\n',
#  '    NHGIS code:  B8X\n',
#  ' \n',
#  '14. Families by Income in 1959\n',
#  '    Universe:    Puerto Rican or Spanish Surname Families\n',
#  '    Source code: NT36A\n',
#  '    NHGIS code:  B8Y\n',
#  ' \n',
#  '15. Occupied Housing Units by Tenure\n',
#  '    Universe:    Occupied Housing Units\n',
#  '    Source code: NT58\n',
#  '    NHGIS code:  B9O\n',
#  ' \n',
#  '16. Occupied Housing Units by Tenure\n',
#  '    Universe:    Occupied Housing Units with Nonwhite Householder\n',
#  '    Source code: NT59\n',
#  '    NHGIS code:  B9P\n',
#  ' \n',
#  '17. Vacant Housing Units by Vacancy Status\n',
#  '    Universe:    Vacant Housing Units\n',
#  '    Source code: NT60\n',
#  '    NHGIS code:  B9R\n',
#  ' \n',
#  '18. Total Nonwhite Population\n',
#  '    Universe:    Nonwhite Persons\n',
#  '    Source code: NT62\n',
#  '    NHGIS code:  B9T\n',
#  ' \n',
#  '19. Total Population [from printed report]\n',
#  '    Universe:    Persons\n',
#  '    Source code: NBT1\n',
#  '    NHGIS code:  B53\n',
#  ' \n',
#  '20. Total Population [from printed report]\n',
#  '    Universe:    Persons\n',
#  '    Source code: NBT4\n',
#  '    NHGIS code:  B60\n',
#  ' \n',
#  '21. Population by Race [from printed report]\n',
#  '    Universe:    Persons\n',
#  '    Source code: NBT5\n',
#  '    NHGIS code:  B7B\n',
#  ' \n',
#  '22. Population Aged 25 Years or More by Years of School Completed [from printed report]\n',
#  '    Universe:    Persons 25 Years and Over\n',
#  '    Source code: NBT17\n',
#  '    NHGIS code:  B6B\n',
#  ' \n',
#  '23. Unrelated Individual Income in 1959 [from printed report]\n',
#  '    Universe:    Unrelated Individuals in 1959\n',
#  '    Source code: NBT20\n',
#  '    NHGIS code:  B6F\n',
#  ' \n',
#  '24. White Population by Sex [from printed report]\n',
#  '    Universe:    White Persons\n',
#  '    Source code: NBT24\n',
#  '    NHGIS code:  B6J\n',
#  ' \n',
#  '25. Total House Units [from printed report]\n',
#  '    Universe:    House Units\n',
#  '    Source code: NBT40\n',
#  '    NHGIS code:  B61\n',
#  ' \n',
#  '26. All Housing Units [from printed report]\n',
#  '    Universe:    Housing Units\n',
#  '    Source code: NBT41\n',
#  '    NHGIS code:  B62\n',
#  ' \n',
#  '27. Occupied Housing Units by Tenure [from printed report]\n',
#  '    Universe:    Occupied Housing Units\n',
#  '    Source code: NBT42\n',
#  '    NHGIS code:  B63\n',
#  ' \n',
#  '28. Occupied Housing Units by Tenure Status by Race of Occupant [from printed report]\n',
#  '    Universe:    Occupied Housing Units\n',
#  '    Source code: NBT43\n',
#  '    NHGIS code:  B64\n',
#  ' \n',
#  '29. Housing Units by Vacancy [from printed report]\n',
#  '    Universe:    Housing Units\n',
#  '    Source code: NBT44\n',
#  '    NHGIS code:  B65\n',
#  ' \n',
#  '--------------------------------------------------------------------------------\n',
#  'Data Dictionary\n',
#  '--------------------------------------------------------------------------------\n',
#  ' \n',
#  'Context Fields \n',
#  '    GISJOIN:     GIS Join Match Code\n',
#  '    YEAR:        Data File Year\n',
#  '    STATE:       State Name\n',
#  '    STATEA:      State Code\n',
#  '    COUNTY:      County Name\n',
#  '    COUNTYA:     County Code\n',
#  '    PRETRACTA:   Census Tract Prefix Code\n',
#  '    TRACTA:      Census Tract Code\n',
#  '    POSTTRCTA:   Census Tract Suffix Code\n',
#  '    AREANAME:    Area Name\n',
#  ' \n',
#  'Table 1:     Total Persons\n',
#  'Universe:    Persons\n',
#  'Source code: NTSUP2\n',
#  'NHGIS code:  CA4\n',
#  '    CA4001:      Total\n',
#  ' \n',
#  'Table 2:     Total Housing Units\n',
#  'Universe:    Housing Units\n',
#  'Source code: NTSUP3\n',
#  'NHGIS code:  CA5\n',
#  '    CA5001:      Total\n',
#  ' \n',
#  'Table 3:     Owner-Occupied Housing Units Reporting Value\n',
#  'Universe:    Owner-Occupied Housing Units Reporting Value\n',
#  'Source code: NTSUP4\n',
#  'NHGIS code:  CA6\n',
#  '    CA6001:      Total\n',
#  ' \n',
#  'Table 4:     White Persons by Household Relationship\n',
#  'Universe:    White Persons\n',
#  'Source code: NT1\n',
#  'NHGIS code:  B7Z\n',
#  '    B7Z001:      Head of primary family\n',
#  '    B7Z002:      Primary individual\n',
#  '    B7Z003:      Wife of head\n',
#  '    B7Z004:      Related single child under 18\n',
#  '    B7Z005:      Other relative of head\n',
#  '    B7Z006:      Non-relative of head\n',
#  '    B7Z007:      Inmate of institution\n',
#  '    B7Z008:      Other in group quarters\n',
#  ' \n',
#  'Table 5:     Occupied Year-Round Housing Units by Tenure\n',
#  'Universe:    Occupied Year-Round Housing Units\n',
#  'Source code: NT2\n',
#  'NHGIS code:  B8F\n',
#  '    B8F001:      Owner-occupied\n',
#  '    B8F002:      Renter-occupied\n',
#  ' \n',
#  'Table 6:     Vacant Year-Round Housing Units by Occupancy/Vacancy Status\n',
#  'Universe:    Vacant Year-Round Housing Units\n',
#  'Source code: NT3\n',
#  'NHGIS code:  B8Q\n',
#  '    B8Q001:      Vacant for rent\n',
#  '    B8Q002:      Vacant for sale\n',
#  ' \n',
#  'Table 7:     Nonwhite Persons by Race by Sex\n',
#  'Universe:    Nonwhite Persons\n',
#  'Source code: NT17\n',
#  'NHGIS code:  B8C\n',
#  '    B8C001:      Negroes >> Male\n',
#  '    B8C002:      Negroes >> Female\n',
#  '    B8C003:      Other Nonwhites >> Male\n',
#  '    B8C004:      Other Nonwhites >> Female\n',
#  ' \n',
#  'Table 8:     Persons by Race by Age by Sex\n',
#  'Universe:    Persons\n',
#  'Source code: NT20\n',
#  'NHGIS code:  B8G\n',
#  '    B8G001:      White >> Under 5 years >> Male\n',
#  '    B8G002:      White >> Under 5 years >> Female\n',
#  '    B8G003:      White >> 5-9 Years >> Male\n',
#  '    B8G004:      White >> 5-9 Years >> Female\n',
#  '    B8G005:      White >> 10-14 years >> Male\n',
#  '    B8G006:      White >> 10-14 years >> Female\n',
#  '    B8G007:      White >> 15-19 years >> Male\n',
#  '    B8G008:      White >> 15-19 years >> Female\n',
#  '    B8G009:      White >> 20-24 years >> Male\n',
#  '    B8G010:      White >> 20-24 years >> Female\n',
#  '    B8G011:      White >> 25-29 years >> Male\n',
#  '    B8G012:      White >> 25-29 years >> Female\n',
#  '    B8G013:      White >> 30-34 years >> Male\n',
#  '    B8G014:      White >> 30-34 years >> Female\n',
#  '    B8G015:      White >> 35-39 years >> Male\n',
#  '    B8G016:      White >> 35-39 years >> Female\n',
#  '    B8G017:      White >> 40-44 years >> Male\n',
#  '    B8G018:      White >> 40-44 years >> Female\n',
#  '    B8G019:      White >> 45-49 years >> Male\n',
#  '    B8G020:      White >> 45-49 years >> Female\n',
#  '    B8G021:      White >> 50-54 years >> Male\n',
#  '    B8G022:      White >> 50-54 years >> Female\n',
#  '    B8G023:      White >> 55-59 years >> Male\n',
#  '    B8G024:      White >> 55-59 years >> Female\n',
#  '    B8G025:      White >> 60-64 years >> Male\n',
#  '    B8G026:      White >> 60-64 years >> Female\n',
#  '    B8G027:      White >> 65-69 years >> Male\n',
#  '    B8G028:      White >> 65-69 years >> Female\n',
#  '    B8G029:      White >> 70-74 years >> Male\n',
#  '    B8G030:      White >> 70-74 years >> Female\n',
#  '    B8G031:      White >> 75 years and over >> Male\n',
#  '    B8G032:      White >> 75 years and over >> Female\n',
#  '    B8G033:      Non-white >> Under 5 years >> Male\n',
#  '    B8G034:      Non-white >> Under 5 years >> Female\n',
#  '    B8G035:      Non-white >> 5-9 Years >> Male\n',
#  '    B8G036:      Non-white >> 5-9 Years >> Female\n',
#  '    B8G037:      Non-white >> 10-14 years >> Male\n',
#  '    B8G038:      Non-white >> 10-14 years >> Female\n',
#  '    B8G039:      Non-white >> 15-19 years >> Male\n',
#  '    B8G040:      Non-white >> 15-19 years >> Female\n',
#  '    B8G041:      Non-white >> 20-24 years >> Male\n',
#  '    B8G042:      Non-white >> 20-24 years >> Female\n',
#  '    B8G043:      Non-white >> 25-29 years >> Male\n',
#  '    B8G044:      Non-white >> 25-29 years >> Female\n',
#  '    B8G045:      Non-white >> 30-34 years >> Male\n',
#  '    B8G046:      Non-white >> 30-34 years >> Female\n',
#  '    B8G047:      Non-white >> 35-39 years >> Male\n',
#  '    B8G048:      Non-white >> 35-39 years >> Female\n',
#  '    B8G049:      Non-white >> 40-44 years >> Male\n',
#  '    B8G050:      Non-white >> 40-44 years >> Female\n',
#  '    B8G051:      Non-white >> 45-49 years >> Male\n',
#  '    B8G052:      Non-white >> 45-49 years >> Female\n',
#  '    B8G053:      Non-white >> 50-54 years >> Male\n',
#  '    B8G054:      Non-white >> 50-54 years >> Female\n',
#  '    B8G055:      Non-white >> 55-59 years >> Male\n',
#  '    B8G056:      Non-white >> 55-59 years >> Female\n',
#  '    B8G057:      Non-white >> 60-64 years >> Male\n',
#  '    B8G058:      Non-white >> 60-64 years >> Female\n',
#  '    B8G059:      Non-white >> 65-69 years >> Male\n',
#  '    B8G060:      Non-white >> 65-69 years >> Female\n',
#  '    B8G061:      Non-white >> 70-74 years >> Male\n',
#  '    B8G062:      Non-white >> 70-74 years >> Female\n',
#  '    B8G063:      Non-white >> 75 years and over >> Male\n',
#  '    B8G064:      Non-white >> 75 years and over >> Female\n',
#  ' \n',
#  'Table 9:     Persons 25 Years and Over by Years of School Completed\n',
#  'Universe:    Persons 25 Years and Over\n',
#  'Source code: NT30\n',
#  'NHGIS code:  B8R\n',
#  '    B8R001:      No school years completed\n',
#  '    B8R002:      1 to 4 years\n',
#  '    B8R003:      5 to 7 years\n',
#  '    B8R004:      8 years\n',
#  '    B8R005:      High School, 1 to 3 years\n',
#  '    B8R006:      High School, 4 years\n',
#  '    B8R007:      College, 1 to 3 years\n',
#  '    B8R008:      College, 4 or more years\n',
#  ' \n',
#  'Table 10:    Persons 25 Years and Over by Years of School Completed\n',
#  'Universe:    Nonwhite Persons 25 Years and Over\n',
#  'Source code: NT31\n',
#  'NHGIS code:  B8S\n',
#  '    B8S001:      No school years completed\n',
#  '    B8S002:      1 to 4 years\n',
#  '    B8S003:      5 to 7 years\n',
#  '    B8S004:      8 years\n',
#  '    B8S005:      High School, 1 to 3 years\n',
#  '    B8S006:      High School, 4 years\n',
#  '    B8S007:      College, 1 to 3 years\n',
#  '    B8S008:      College, 4 or more years\n',
#  ' \n',
#  'Table 11:    Persons 25 Years and Over by Years of School Completed\n',
#  'Universe:    Puerto Rican or Spanish Surname Persons 25 Years and Over\n',
#  'Source code: NT32\n',
#  'NHGIS code:  B8T\n',
#  '    B8T001:      No school years completed\n',
#  '    B8T002:      1 to 4 years\n',
#  '    B8T003:      5 to 7 years\n',
#  '    B8T004:      8 years\n',
#  '    B8T005:      High School, 1 to 3 years\n',
#  '    B8T006:      High School, 4 years\n',
#  '    B8T007:      College, 1 to 3 years\n',
#  '    B8T008:      College, 4 or more years\n',
#  ' \n',
#  'Table 12:    Families by Income in 1959\n',
#  'Universe:    Families\n',
#  'Source code: NT35\n',
#  'NHGIS code:  B8W\n',
#  '    B8W001:      Less than $1,000\n',
#  '    B8W002:      $1,000-$1,999\n',
#  '    B8W003:      $2,000-$2,999\n',
#  '    B8W004:      $3,000-$3,999\n',
#  '    B8W005:      $4,000-$4,999\n',
#  '    B8W006:      $5,000-$5,999\n',
#  '    B8W007:      $6,000-$6,999\n',
#  '    B8W008:      $7,000-$7,999\n',
#  '    B8W009:      $8,000-$8,999\n',
#  '    B8W010:      $9,000-$9,999\n',
#  '    B8W011:      $10,000-$14,999\n',
#  '    B8W012:      $15,000-$24,999\n',
#  '    B8W013:      $25,000 and over\n',
#  ' \n',
#  'Table 13:    Nonwhite Families by Income in 1959\n',
#  'Universe:    Nonwhite Families\n',
#  'Source code: NT36\n',
#  'NHGIS code:  B8X\n',
#  '    B8X001:      Less than $1,000\n',
#  '    B8X002:      $1,000-$1,999\n',
#  '    B8X003:      $2,000-$2,999\n',
#  '    B8X004:      $3,000-$3,999\n',
#  '    B8X005:      $4,000-$4,999\n',
#  '    B8X006:      $5,000-$5,999\n',
#  '    B8X007:      $6,000-$6,999\n',
#  '    B8X008:      $7,000-$7,999\n',
#  '    B8X009:      $8,000-$8,999\n',
#  '    B8X010:      $9,000-$9,999\n',
#  '    B8X011:      $10,000 and over\n',
#  ' \n',
#  'Table 14:    Families by Income in 1959\n',
#  'Universe:    Puerto Rican or Spanish Surname Families\n',
#  'Source code: NT36A\n',
#  'NHGIS code:  B8Y\n',
#  '    B8Y001:      Less than $1,000\n',
#  '    B8Y002:      $1,000-$1,999\n',
#  '    B8Y003:      $2,000-$2,999\n',
#  '    B8Y004:      $3,000-$3,999\n',
#  '    B8Y005:      $4,000-$4,999\n',
#  '    B8Y006:      $5,000-$5,999\n',
#  '    B8Y007:      $6,000-$6,999\n',
#  '    B8Y008:      $7,000-$7,999\n',
#  '    B8Y009:      $8,000-$8,999\n',
#  '    B8Y010:      $9,000-$9,999\n',
#  '    B8Y011:      $10,000 and over\n',
#  ' \n',
#  'Table 15:    Occupied Housing Units by Tenure\n',
#  'Universe:    Occupied Housing Units\n',
#  'Source code: NT58\n',
#  'NHGIS code:  B9O\n',
#  '    B9O001:      Owner-occupied\n',
#  '    B9O002:      Renter-occupied\n',
#  ' \n',
#  'Table 16:    Occupied Housing Units by Tenure\n',
#  'Universe:    Occupied Housing Units with Nonwhite Householder\n',
#  'Source code: NT59\n',
#  'NHGIS code:  B9P\n',
#  '    B9P001:      Owner-occupied\n',
#  '    B9P002:      Renter-occupied\n',
#  ' \n',
#  'Table 17:    Vacant Housing Units by Vacancy Status\n',
#  'Universe:    Vacant Housing Units\n',
#  'Source code: NT60\n',
#  'NHGIS code:  B9R\n',
#  '    B9R001:      Vacant for sale only\n',
#  '    B9R002:      Vacant for rent\n',
#  '    B9R003:      Other vacant (includes seasonal and migratory)\n',
#  ' \n',
#  'Table 18:    Total Nonwhite Population\n',
#  'Universe:    Nonwhite Persons\n',
#  'Source code: NT62\n',
#  'NHGIS code:  B9T\n',
#  '    B9T001:      Total\n',
#  ' \n',
#  'Table 19:    Total Population [from printed report]\n',
#  'Universe:    Persons\n',
#  'Source code: NBT1\n',
#  'NHGIS code:  B53\n',
#  '    B53001:      Total\n',
#  ' \n',
#  'Table 20:    Total Population [from printed report]\n',
#  'Universe:    Persons\n',
#  'Source code: NBT4\n',
#  'NHGIS code:  B60\n',
#  '    B60001:      Total\n',
#  ' \n',
#  'Table 21:    Population by Race [from printed report]\n',
#  'Universe:    Persons\n',
#  'Source code: NBT5\n',
#  'NHGIS code:  B7B\n',
#  '    B7B001:      White\n',
#  '    B7B002:      Negro\n',
#  '    B7B003:      Other races\n',
#  ' \n',
#  'Table 22:    Population Aged 25 Years or More by Years of School Completed [from printed report]\n',
#  'Universe:    Persons 25 Years and Over\n',
#  'Source code: NBT17\n',
#  'NHGIS code:  B6B\n',
#  '    B6B001:      No school years completed\n',
#  '    B6B002:      Elementary 1-4\n',
#  '    B6B003:      Elementary 5-7\n',
#  '    B6B004:      Elementary 8\n',
#  '    B6B005:      High school 1-3\n',
#  '    B6B006:      High school 4\n',
#  '    B6B007:      College 1-3\n',
#  '    B6B008:      College 4 plus\n',
#  ' \n',
#  'Table 23:    Unrelated Individual Income in 1959 [from printed report]\n',
#  'Universe:    Unrelated Individuals in 1959\n',
#  'Source code: NBT20\n',
#  'NHGIS code:  B6F\n',
#  '    B6F001:      Under $1000\n',
#  '    B6F002:      $1000 - $1999\n',
#  '    B6F003:      $2000 - $2999\n',
#  '    B6F004:      $3000 - $3999\n',
#  '    B6F005:      $4000 - $4999\n',
#  '    B6F006:      $5000 - $5999\n',
#  '    B6F007:      $6000 - $6999\n',
#  '    B6F008:      $7000 - $7999\n',
#  '    B6F009:      $8000 - $8999\n',
#  '    B6F010:      $9000 - $9999\n',
#  '    B6F011:      $10000 - $14999\n',
#  '    B6F012:      $15000 - $24999\n',
#  '    B6F013:      $25000 plus\n',
#  ' \n',
#  'Table 24:    White Population by Sex [from printed report]\n',
#  'Universe:    White Persons\n',
#  'Source code: NBT24\n',
#  'NHGIS code:  B6J\n',
#  '    B6J001:      Male\n',
#  '    B6J002:      Female\n',
#  ' \n',
#  'Table 25:    Total House Units [from printed report]\n',
#  'Universe:    House Units\n',
#  'Source code: NBT40\n',
#  'NHGIS code:  B61\n',
#  '    B61001:      Total\n',
#  ' \n',
#  'Table 26:    All Housing Units [from printed report]\n',
#  'Universe:    Housing Units\n',
#  'Source code: NBT41\n',
#  'NHGIS code:  B62\n',
#  '    B62001:      Total\n',
#  ' \n',
#  'Table 27:    Occupied Housing Units by Tenure [from printed report]\n',
#  'Universe:    Occupied Housing Units\n',
#  'Source code: NBT42\n',
#  'NHGIS code:  B63\n',
#  '    B63001:      Owner-occupied\n',
#  '    B63002:      Renter-occupied\n',
#  ' \n',
#  'Table 28:    Occupied Housing Units by Tenure Status by Race of Occupant [from printed report]\n',
#  'Universe:    Occupied Housing Units\n',
#  'Source code: NBT43\n',
#  'NHGIS code:  B64\n',
#  '    B64001:      Owner-occupied >> White\n',
#  '    B64002:      Owner-occupied >> Non-white\n',
#  '    B64003:      Renter-occupied >> White\n',
#  '    B64004:      Renter-occupied >> Non-white\n',
#  ' \n',
#  'Table 29:    Housing Units by Vacancy [from printed report]\n',
#  'Universe:    Housing Units\n',
#  'Source code: NBT44\n',
#  'NHGIS code:  B65\n',
#  '    B65001:      Available vacant\n',
#  '    B65002:      Other vacant\n',
#  ' \n',
#  '--------------------------------------------------------------------------------\n',
#  'Citation and Use of NHGIS Data\n',
#  '--------------------------------------------------------------------------------\n',
#  ' \n',
#  'All persons are granted a limited license to use this documentation and the\n',
#  'accompanying data, subject to the following conditions:\n',
#  '\n',
#  '* Publications and research reports employing NHGIS data (either tabular or GIS)\n',
#  '  must cite it appropriately. The citation should include the following:\n',
#  '\n',
#  '    Steven Manson, Jonathan Schroeder, David Van Riper, and Steven Ruggles. \n',
#  '    IPUMS National Historical Geographic Information System: Version 12.0 [Database]. \n',
#  '    Minneapolis: University of Minnesota. 2017. \n',
#  '    http://doi.org/10.18128/D050.V12.0\n',
#  '\n',
#  '* Publications and research reports employing school attendance areas data\n',
#  '  (either tabular or GIS) must cite it appropriately. The citation should\n',
#  '  include the following:\n',
#  '\n',
#  '    The College of William and Mary and the Minnesota Population Center.\n',
#  '    School Attendance Boundary Information System (SABINS): Version 1.0.\n',
#  '    Minneapolis, MN: University of Minnesota 2011.\n',
#  '\n',
#  '* For policy briefs or articles in the popular press, we recommend that you cite the use of NHGIS data as follows:\n',
#  '\n',
#  '    IPUMS NHGIS, University of Minnesota, www.nhgis.org.\n',
#  '\n',
#  '* If possible, citations involving school attendance areas should also include\n',
#  '  the URL for the SABINS site:\n',
#  '\n',
#  '    http://www.sabinsdata.org/.\n',
#  '\n',
#  'In addition, we request that users send us a copy of any publications, research\n',
#  'reports, or educational material making use of the data or documentation.\n',
#  'Printed matter should be sent to:\n',
#  '\n',
#  '    NHGIS\n',
#  '    Minnesota Population Center\n',
#  '    University of Minnesota\n',
#  '    50 Willey Hall\n',
#  '    225 19th Ave S\n',
#  '    Minneapolis, MN 55455\n',
#  '\n',
#  'Send electronic material to: nhgis@umn.edu\n']

# %%
# regex to save lines that start with #.,  "NHGIS code:"
tab = []
code = []
mini_code = {}

for line in lines:
    if re.match('[0-9]+', line):
        temp = re.sub('[0-9]*\. ', '', line)
        temp = re.sub(' ', '_', temp)
        tab.append(temp[:-1])
    if re.match('NHGIS code:', line):
        code.append(line[-4:-1])
    if re.match('.*[0-9]{3}:', line):
        preproc = re.sub(' ', '', line)
        preproc = re.sub('\n', '', preproc)
        c, n = preproc.split(":")[0], "_".join(preproc.split(":")[1:])
        threeletter = c[:3]
        store = mini_code.get(threeletter, {})
        store[c] = n
        mini_code[threeletter] = store

# %%
# construct a dictionary of code to table
code_dict = {}

for i, c in enumerate(code):
    code_dict[c] = tab[i]

# %%
# convert the pd cols from NHGIS names
data = pd.read_csv(DATAFILE)

# only keep IL
working_df = data[(data.STATE == 'Illinois') & (data.COUNTY == 'Cook')]

# %%
new_cols = []
for colname in working_df.columns:
    if colname[:3] in code_dict.keys():
        sub_cat_dict = mini_code.get(colname[:3], {}) 
        subcat = sub_cat_dict[colname]
        keep = code_dict[colname[:3]]+"_"+ subcat
    else: 
        keep = colname
    new_cols.append(keep)

# %%
working_df.columns = new_cols

# %%
working_df.columns
# Out:
# Index(['GISJOIN', 'YEAR', 'STATE', 'STATEA', 'COUNTY', 'COUNTYA', 'PRETRACTA',
#        'TRACTA', 'POSTTRCTA', 'AREANAME', 'Total_Persons_Total',
#        'Total_Housing_Units_Total',
#        'Owner-Occupied_Housing_Units_Reporting_Value_Total',
#        'White_Persons_by_Household_Relationship_Headofprimaryfamily',
#        'White_Persons_by_Household_Relationship_Primaryindividual',
#        'White_Persons_by_Household_Relationship_Wifeofhead',
#        'White_Persons_by_Household_Relationship_Relatedsinglechildunder18',
#        'White_Persons_by_Household_Relationship_Otherrelativeofhead',
#        'White_Persons_by_Household_Relationship_Non-relativeofhead',
#        'White_Persons_by_Household_Relationship_Inmateofinstitution',
#        'White_Persons_by_Household_Relationship_Otheringroupquarters',
#        'Occupied_Year-Round_Housing_Units_by_Tenure_Owner-occupied',
#        'Occupied_Year-Round_Housing_Units_by_Tenure_Renter-occupied',
#        'Vacant_Year-Round_Housing_Units_by_Occupancy/Vacancy_Status_Vacantforrent',
#        'Vacant_Year-Round_Housing_Units_by_Occupancy/Vacancy_Status_Vacantforsale',
#        'Nonwhite_Persons_by_Race_by_Sex_Negroes>>Male',
#        'Nonwhite_Persons_by_Race_by_Sex_Negroes>>Female',
#        'Nonwhite_Persons_by_Race_by_Sex_OtherNonwhites>>Male',
#        'Nonwhite_Persons_by_Race_by_Sex_OtherNonwhites>>Female',
#        'Persons_by_Race_by_Age_by_Sex_White>>Under5years>>Male',
#        'Persons_by_Race_by_Age_by_Sex_White>>Under5years>>Female',
#        'Persons_by_Race_by_Age_by_Sex_White>>5-9Years>>Male',
#        'Persons_by_Race_by_Age_by_Sex_White>>5-9Years>>Female',
#        'Persons_by_Race_by_Age_by_Sex_White>>10-14years>>Male',
#        'Persons_by_Race_by_Age_by_Sex_White>>10-14years>>Female',
#        'Persons_by_Race_by_Age_by_Sex_White>>15-19years>>Male',
#        'Persons_by_Race_by_Age_by_Sex_White>>15-19years>>Female',
#        'Persons_by_Race_by_Age_by_Sex_White>>20-24years>>Male',
#        'Persons_by_Race_by_Age_by_Sex_White>>20-24years>>Female',
#        'Persons_by_Race_by_Age_by_Sex_White>>25-29years>>Male',
#        'Persons_by_Race_by_Age_by_Sex_White>>25-29years>>Female',
#        'Persons_by_Race_by_Age_by_Sex_White>>30-34years>>Male',
#        'Persons_by_Race_by_Age_by_Sex_White>>30-34years>>Female',
#        'Persons_by_Race_by_Age_by_Sex_White>>35-39years>>Male',
#        'Persons_by_Race_by_Age_by_Sex_White>>35-39years>>Female',
#        'Persons_by_Race_by_Age_by_Sex_White>>40-44years>>Male',
#        'Persons_by_Race_by_Age_by_Sex_White>>40-44years>>Female',
#        'Persons_by_Race_by_Age_by_Sex_White>>45-49years>>Male',
#        'Persons_by_Race_by_Age_by_Sex_White>>45-49years>>Female',
#        'Persons_by_Race_by_Age_by_Sex_White>>50-54years>>Male',
#        'Persons_by_Race_by_Age_by_Sex_White>>50-54years>>Female',
#        'Persons_by_Race_by_Age_by_Sex_White>>55-59years>>Male',
#        'Persons_by_Race_by_Age_by_Sex_White>>55-59years>>Female',
#        'Persons_by_Race_by_Age_by_Sex_White>>60-64years>>Male',
#        'Persons_by_Race_by_Age_by_Sex_White>>60-64years>>Female',
#        'Persons_by_Race_by_Age_by_Sex_White>>65-69years>>Male',
#        'Persons_by_Race_by_Age_by_Sex_White>>65-69years>>Female',
#        'Persons_by_Race_by_Age_by_Sex_White>>70-74years>>Male',
#        'Persons_by_Race_by_Age_by_Sex_White>>70-74years>>Female',
#        'Persons_by_Race_by_Age_by_Sex_White>>75yearsandover>>Male',
#        'Persons_by_Race_by_Age_by_Sex_White>>75yearsandover>>Female',
#        'Persons_by_Race_by_Age_by_Sex_Non-white>>Under5years>>Male',
#        'Persons_by_Race_by_Age_by_Sex_Non-white>>Under5years>>Female',
#        'Persons_by_Race_by_Age_by_Sex_Non-white>>5-9Years>>Male',
#        'Persons_by_Race_by_Age_by_Sex_Non-white>>5-9Years>>Female',
#        'Persons_by_Race_by_Age_by_Sex_Non-white>>10-14years>>Male',
#        'Persons_by_Race_by_Age_by_Sex_Non-white>>10-14years>>Female',
#        'Persons_by_Race_by_Age_by_Sex_Non-white>>15-19years>>Male',
#        'Persons_by_Race_by_Age_by_Sex_Non-white>>15-19years>>Female',
#        'Persons_by_Race_by_Age_by_Sex_Non-white>>20-24years>>Male',
#        'Persons_by_Race_by_Age_by_Sex_Non-white>>20-24years>>Female',
#        'Persons_by_Race_by_Age_by_Sex_Non-white>>25-29years>>Male',
#        'Persons_by_Race_by_Age_by_Sex_Non-white>>25-29years>>Female',
#        'Persons_by_Race_by_Age_by_Sex_Non-white>>30-34years>>Male',
#        'Persons_by_Race_by_Age_by_Sex_Non-white>>30-34years>>Female',
#        'Persons_by_Race_by_Age_by_Sex_Non-white>>35-39years>>Male',
#        'Persons_by_Race_by_Age_by_Sex_Non-white>>35-39years>>Female',
#        'Persons_by_Race_by_Age_by_Sex_Non-white>>40-44years>>Male',
#        'Persons_by_Race_by_Age_by_Sex_Non-white>>40-44years>>Female',
#        'Persons_by_Race_by_Age_by_Sex_Non-white>>45-49years>>Male',
#        'Persons_by_Race_by_Age_by_Sex_Non-white>>45-49years>>Female',
#        'Persons_by_Race_by_Age_by_Sex_Non-white>>50-54years>>Male',
#        'Persons_by_Race_by_Age_by_Sex_Non-white>>50-54years>>Female',
#        'Persons_by_Race_by_Age_by_Sex_Non-white>>55-59years>>Male',
#        'Persons_by_Race_by_Age_by_Sex_Non-white>>55-59years>>Female',
#        'Persons_by_Race_by_Age_by_Sex_Non-white>>60-64years>>Male',
#        'Persons_by_Race_by_Age_by_Sex_Non-white>>60-64years>>Female',
#        'Persons_by_Race_by_Age_by_Sex_Non-white>>65-69years>>Male',
#        'Persons_by_Race_by_Age_by_Sex_Non-white>>65-69years>>Female',
#        'Persons_by_Race_by_Age_by_Sex_Non-white>>70-74years>>Male',
#        'Persons_by_Race_by_Age_by_Sex_Non-white>>70-74years>>Female',
#        'Persons_by_Race_by_Age_by_Sex_Non-white>>75yearsandover>>Male',
#        'Persons_by_Race_by_Age_by_Sex_Non-white>>75yearsandover>>Female',
#        'Persons_25_Years_and_Over_by_Years_of_School_Completed_Noschoolyearscompleted',
#        'Persons_25_Years_and_Over_by_Years_of_School_Completed_1to4years',
#        'Persons_25_Years_and_Over_by_Years_of_School_Completed_5to7years',
#        'Persons_25_Years_and_Over_by_Years_of_School_Completed_8years',
#        'Persons_25_Years_and_Over_by_Years_of_School_Completed_HighSchool,1to3years',
#        'Persons_25_Years_and_Over_by_Years_of_School_Completed_HighSchool,4years',
#        'Persons_25_Years_and_Over_by_Years_of_School_Completed_College,1to3years',
#        'Persons_25_Years_and_Over_by_Years_of_School_Completed_College,4ormoreyears',
#        'Persons_25_Years_and_Over_by_Years_of_School_Completed_Noschoolyearscompleted',
#        'Persons_25_Years_and_Over_by_Years_of_School_Completed_1to4years',
#        'Persons_25_Years_and_Over_by_Years_of_School_Completed_5to7years',
#        'Persons_25_Years_and_Over_by_Years_of_School_Completed_8years',
#        'Persons_25_Years_and_Over_by_Years_of_School_Completed_HighSchool,1to3years',
#        'Persons_25_Years_and_Over_by_Years_of_School_Completed_HighSchool,4years',
#        'Persons_25_Years_and_Over_by_Years_of_School_Completed_College,1to3years',
#        'Persons_25_Years_and_Over_by_Years_of_School_Completed_College,4ormoreyears',
#        'Persons_25_Years_and_Over_by_Years_of_School_Completed_Noschoolyearscompleted',
#        'Persons_25_Years_and_Over_by_Years_of_School_Completed_1to4years',
#        'Persons_25_Years_and_Over_by_Years_of_School_Completed_5to7years',
#        'Persons_25_Years_and_Over_by_Years_of_School_Completed_8years',
#        'Persons_25_Years_and_Over_by_Years_of_School_Completed_HighSchool,1to3years',
#        'Persons_25_Years_and_Over_by_Years_of_School_Completed_HighSchool,4years',
#        'Persons_25_Years_and_Over_by_Years_of_School_Completed_College,1to3years',
#        'Persons_25_Years_and_Over_by_Years_of_School_Completed_College,4ormoreyears',
#        'Families_by_Income_in_1959_Lessthan$1,000',
#        'Families_by_Income_in_1959_$1,000-$1,999',
#        'Families_by_Income_in_1959_$2,000-$2,999',
#        'Families_by_Income_in_1959_$3,000-$3,999',
#        'Families_by_Income_in_1959_$4,000-$4,999',
#        'Families_by_Income_in_1959_$5,000-$5,999',
#        'Families_by_Income_in_1959_$6,000-$6,999',
#        'Families_by_Income_in_1959_$7,000-$7,999',
#        'Families_by_Income_in_1959_$8,000-$8,999',
#        'Families_by_Income_in_1959_$9,000-$9,999',
#        'Families_by_Income_in_1959_$10,000-$14,999',
#        'Families_by_Income_in_1959_$15,000-$24,999',
#        'Families_by_Income_in_1959_$25,000andover',
#        'Nonwhite_Families_by_Income_in_1959_Lessthan$1,000',
#        'Nonwhite_Families_by_Income_in_1959_$1,000-$1,999',
#        'Nonwhite_Families_by_Income_in_1959_$2,000-$2,999',
#        'Nonwhite_Families_by_Income_in_1959_$3,000-$3,999',
#        'Nonwhite_Families_by_Income_in_1959_$4,000-$4,999',
#        'Nonwhite_Families_by_Income_in_1959_$5,000-$5,999',
#        'Nonwhite_Families_by_Income_in_1959_$6,000-$6,999',
#        'Nonwhite_Families_by_Income_in_1959_$7,000-$7,999',
#        'Nonwhite_Families_by_Income_in_1959_$8,000-$8,999',
#        'Nonwhite_Families_by_Income_in_1959_$9,000-$9,999',
#        'Nonwhite_Families_by_Income_in_1959_$10,000andover',
#        'Families_by_Income_in_1959_Lessthan$1,000',
#        'Families_by_Income_in_1959_$1,000-$1,999',
#        'Families_by_Income_in_1959_$2,000-$2,999',
#        'Families_by_Income_in_1959_$3,000-$3,999',
#        'Families_by_Income_in_1959_$4,000-$4,999',
#        'Families_by_Income_in_1959_$5,000-$5,999',
#        'Families_by_Income_in_1959_$6,000-$6,999',
#        'Families_by_Income_in_1959_$7,000-$7,999',
#        'Families_by_Income_in_1959_$8,000-$8,999',
#        'Families_by_Income_in_1959_$9,000-$9,999',
#        'Families_by_Income_in_1959_$10,000andover',
#        'Occupied_Housing_Units_by_Tenure_Owner-occupied',
#        'Occupied_Housing_Units_by_Tenure_Renter-occupied',
#        'Occupied_Housing_Units_by_Tenure_Owner-occupied',
#        'Occupied_Housing_Units_by_Tenure_Renter-occupied',
#        'Vacant_Housing_Units_by_Vacancy_Status_Vacantforsaleonly',
#        'Vacant_Housing_Units_by_Vacancy_Status_Vacantforrent',
#        'Vacant_Housing_Units_by_Vacancy_Status_Othervacant(includesseasonalandmigratory)',
#        'Total_Nonwhite_Population_Total',
#        'Total_Population_[from_printed_report]_Total',
#        'Total_Population_[from_printed_report]_Total',
#        'Population_by_Race_[from_printed_report]_White',
#        'Population_by_Race_[from_printed_report]_Negro',
#        'Population_by_Race_[from_printed_report]_Otherraces',
#        'Population_Aged_25_Years_or_More_by_Years_of_School_Completed_[from_printed_report]_Noschoolyearscompleted',
#        'Population_Aged_25_Years_or_More_by_Years_of_School_Completed_[from_printed_report]_Elementary1-4',
#        'Population_Aged_25_Years_or_More_by_Years_of_School_Completed_[from_printed_report]_Elementary5-7',
#        'Population_Aged_25_Years_or_More_by_Years_of_School_Completed_[from_printed_report]_Elementary8',
#        'Population_Aged_25_Years_or_More_by_Years_of_School_Completed_[from_printed_report]_Highschool1-3',
#        'Population_Aged_25_Years_or_More_by_Years_of_School_Completed_[from_printed_report]_Highschool4',
#        'Population_Aged_25_Years_or_More_by_Years_of_School_Completed_[from_printed_report]_College1-3',
#        'Population_Aged_25_Years_or_More_by_Years_of_School_Completed_[from_printed_report]_College4plus',
#        'Unrelated_Individual_Income_in_1959_[from_printed_report]_Under$1000',
#        'Unrelated_Individual_Income_in_1959_[from_printed_report]_$1000-$1999',
#        'Unrelated_Individual_Income_in_1959_[from_printed_report]_$2000-$2999',
#        'Unrelated_Individual_Income_in_1959_[from_printed_report]_$3000-$3999',
#        'Unrelated_Individual_Income_in_1959_[from_printed_report]_$4000-$4999',
#        'Unrelated_Individual_Income_in_1959_[from_printed_report]_$5000-$5999',
#        'Unrelated_Individual_Income_in_1959_[from_printed_report]_$6000-$6999',
#        'Unrelated_Individual_Income_in_1959_[from_printed_report]_$7000-$7999',
#        'Unrelated_Individual_Income_in_1959_[from_printed_report]_$8000-$8999',
#        'Unrelated_Individual_Income_in_1959_[from_printed_report]_$9000-$9999',
#        'Unrelated_Individual_Income_in_1959_[from_printed_report]_$10000-$14999',
#        'Unrelated_Individual_Income_in_1959_[from_printed_report]_$15000-$24999',
#        'Unrelated_Individual_Income_in_1959_[from_printed_report]_$25000plus',
#        'White_Population_by_Sex_[from_printed_report]_Male',
#        'White_Population_by_Sex_[from_printed_report]_Female',
#        'Total_House_Units_[from_printed_report]_Total',
#        'All_Housing_Units_[from_printed_report]_Total',
#        'Occupied_Housing_Units_by_Tenure_[from_printed_report]_Owner-occupied',
#        'Occupied_Housing_Units_by_Tenure_[from_printed_report]_Renter-occupied',
#        'Occupied_Housing_Units_by_Tenure_Status_by_Race_of_Occupant_[from_printed_report]_Owner-occupied>>White',
#        'Occupied_Housing_Units_by_Tenure_Status_by_Race_of_Occupant_[from_printed_report]_Owner-occupied>>Non-white',
#        'Occupied_Housing_Units_by_Tenure_Status_by_Race_of_Occupant_[from_printed_report]_Renter-occupied>>White',
#        'Occupied_Housing_Units_by_Tenure_Status_by_Race_of_Occupant_[from_printed_report]_Renter-occupied>>Non-white',
#        'Housing_Units_by_Vacancy_[from_printed_report]_Availablevacant',
#        'Housing_Units_by_Vacancy_[from_printed_report]_Othervacant'],
#       dtype='object')

# %%
final_df = working_df[['GISJOIN', 'YEAR', 'TRACTA', 'COUNTY', 'STATE']]

# race
final_df = final_df.assign(Totalpop = working_df['Total_Persons_Total'])
final_df = final_df.assign(Pwhite = (final_df.Totalpop - working_df.Total_Nonwhite_Population_Total)/final_df.Totalpop)
final_df = final_df.assign(Pblack = (working_df['Nonwhite_Persons_by_Race_by_Sex_Negroes>>Male'] +
                                     working_df['Nonwhite_Persons_by_Race_by_Sex_Negroes>>Female'])/final_df.Totalpop)
final_df = final_df.assign(Pnonwhite = (working_df['Nonwhite_Persons_by_Race_by_Sex_OtherNonwhites>>Male']+
                                     working_df['Nonwhite_Persons_by_Race_by_Sex_OtherNonwhites>>Female'])/final_df.Totalpop)

# units
final_df = final_df.assign(Totalunits = working_df['Total_House_Units_[from_printed_report]_Total'])

#value = np.where(working_df[
#    'Median_Value_of_Homes_for_Which_Value_was_Reported_Medianvalue'] == 0, 'NaN', 
#                working_df['Median_Value_of_Homes_for_Which_Value_was_Reported_Medianvalue'])
#final_df = final_df.assign(Medianhomeval = value)
Vac = (working_df['Housing_Units_by_Vacancy_[from_printed_report]_Availablevacant'] + 
                          working_df['Housing_Units_by_Vacancy_[from_printed_report]_Othervacant']) / final_df.Totalunits

final_df = final_df.assign(Poccupied = 1-Vac)
final_df = final_df.assign(Pvacant = Vac)

Allowner = working_df['Occupied_Housing_Units_by_Tenure_[from_printed_report]_Owner-occupied']
final_df = final_df.assign(Powner = Allowner / final_df.Totalunits) #check not just of non-vacant

Allrenter = working_df['Occupied_Housing_Units_by_Tenure_[from_printed_report]_Renter-occupied']
final_df = final_df.assign(Prented = Allrenter / final_df.Totalunits)

final_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Total_Occupied_Dwelling_Units_Total'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-59-6d6385981f5e> in <module>()
#      16 #                working_df['Median_Value_of_Homes_for_Which_Value_was_Reported_Medianvalue'])
#      17 #final_df = final_df.assign(Medianhomeval = value)
# ---> 18 final_df = final_df.assign(Poccupied = working_df['Total_Occupied_Dwelling_Units_Total'
#      19                                                  ]/final_df.Totalunits)
#      20 final_df = final_df.assign(Pvacant = 1 - final_df.Poccupied)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1962             return self._getitem_multilevel(key)
#    1963         else:
# -> 1964             return self._getitem_column(key)
#    1965
#    1966     def _getitem_column(self, key):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    1974         result = self._constructor(self._data.get(key))
#    1975         if result.columns.is_unique:
# -> 1976             result = result[key]
#    1977
#    1978         return result
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1962             return self._getitem_multilevel(key)
#    1963         else:
# -> 1964             return self._getitem_column(key)
#    1965
#    1966     def _getitem_column(self, key):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    1969         # get column
#    1970         if self.columns.is_unique:
# -> 1971             return self._get_item_cache(key)
#    1972
#    1973         # duplicate columns & possible reduce dimensionality
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1643         res = cache.get(item)
#    1644         if res is None:
# -> 1645             values = self._data.get(item)
#    1646             res = self._box_item_values(item, values)
#    1647             cache[item] = res
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
# -> 2444                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2445
#    2446         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Total_Occupied_Dwelling_Units_Total'
